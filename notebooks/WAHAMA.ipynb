# %%
import random

random_letter = random.choice('abcdefghijklmnop')
print(random_letter)
# Out:
# j

# %%
import random

random_letter = random.choice('abcdefghijklmnop')
print(random_letter)
# Out:
# p

# %%
import random

random_letter = random.choice('abcdefghijklmnop')
print(random_letter)
# Out:
# l
